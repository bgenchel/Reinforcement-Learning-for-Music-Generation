# %%
# %matplotlib inline
import torch
import json
import matplotlib.pyplot as plt

losses = torch.load('runs/Dec04-18_05:28:32/losses.pt', map_location="cpu")
print(losses.keys())
# Out:
# dict_keys(['adv_gen_losses', 'adv_dscr_losses'])

# %%
import os
os.listdir('.')
# Out:
# ['eval_midi',
#  'data_iter.py',
#  'make_music.py',
#  'Untitled.ipynb',
#  'eval_midi.zip',
#  'gan_loss.py',
#  'generator.py',
#  'temp_data',
#  'rollout.py',
#  '.ipynb_checkpoints',
#  'main.py',
#  'runs',
#  'discriminator.py',
#  'pretrained']

# %%
plt.plot(losses['adv_gen_losses'], 'b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Adversarial Training - Generator Loss")
plt.show()

# %%
plt.plot(losses['adv_dscr_losses'], 'b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Adversarial Training - Discriminator Loss")
plt.show()

# %%
pt_gen_losses = torch.load('pretrained/generator_losses.pt', map_location="cpu")
plt.plot(pt_gen_losses['train_losses'], 'b', label="train")
plt.plot(pt_gen_losses['valid_losses'], 'r', label="valid")
plt.legend(loc='upper right')
plt.title('Generator Pre-Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
pt_dscr_loss = torch.load('pretrained/discriminator_losses.pt', map_location="cpu")
plt.plot(pt_dscr_loss['losses'], 'b')
plt.title('Discriminator Pre-Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
