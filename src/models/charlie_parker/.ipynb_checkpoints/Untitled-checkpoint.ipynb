# %%
# %matplotlib inline
import torch
import json
import matplotlib.pyplot as plt

losses = torch.load('runs/Dec04-18_05:28:32/losses.pt', map_location="cpu")
print(losses.keys())
# Out:
# dict_keys(['adv_gen_losses', 'adv_dscr_losses'])

# %%
import os
os.listdir('.')
# Out:
# ['data_iter.py',
#  'make_music.py',
#  'Untitled.ipynb',
#  'gan_loss.py',
#  'eval_fully_trained',
#  'generator.py',
#  'temp_data',
#  'rollout.py',
#  '.ipynb_checkpoints',
#  'main.py',
#  'runs',
#  'discriminator.py',
#  'pretrained']

# %%
plt.plot(losses['adv_gen_losses'])

# %%
plt.plot(losses['adv_dscr_losses'])

# %%
pt_gen_losses = torch.load('pretrained/generator_losses.pt', map_location="cpu")
print(pt_gen_losses.keys())
plt.plot(pt_gen_losses['loss'])
# Out:
# dict_keys(['train_losses', 'valid_losses'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-24837a067fa9> in <module>()
#       1 pt_gen_losses = torch.load('pretrained/generator_losses.pt', map_location="cpu")
#       2 print(pt_gen_losses.keys())
# ----> 3 plt.plot(pt_gen_losses['loss'])
#
# KeyError: 'loss'
